# %%
#Importing libaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Looking into the dataset

# %%
df = pd.read_csv('Heart_Disease_Prediction.csv')
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# 2                        0         7      Presence
# 3                        1         7       Absence
# 4                        1         3       Absence

# %%
df2 = pd.read_csv('absence_label.csv')
df2.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   67    0                3  115          564             0            2
# 1   64    1                4  128          263             0            0
# 2   74    0                2  120          269             0            2
# 3   65    1                4  120          177             0            0
# 4   59    1                4  135          234             0            0
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     160                0            1.6            2
# 1     105                1            0.2            2
# 2     121                1            0.2            1
# 3     140                0            0.4            1
# 4     161                0            0.5            2
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        0         7       Absence
# 1                        1         7       Absence
# 2                        1         3       Absence
# 3                        0         7       Absence
# 4                        0         7       Absence

# %%
df3 = pd.read_csv('presence_label.csv')
df3.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   57    1                2  124          261             0            0
# 2   56    1                3  130          256             1            2
# 3   59    1                4  110          239             0            2
# 4   60    1                4  140          293             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     141                0            0.3            1
# 2     142                1            0.6            2
# 3     142                1            1.2            2
# 4     170                0            1.2            2
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7      Presence
# 2                        1         6      Presence
# 3                        1         7      Presence
# 4                        2         7      Presence

# %% [markdown]
# Focusing on the 'Heart_Disease_Prediction.csv' dataset

# %%
df.dtypes
# Out:
# Age                          int64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                  int64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# Heart Disease               object
# dtype: object
